# %%
socar_df = pd.read_csv("insurance_fraud_detect_data.csv")
pd.set_option('display.max_columns', len(socar_df.columns))
socar_df.head()
# Out:
#    fraud_YN  car_model  sharing_type  age_group  has_previous_accident  \
# 0         0          2             1          3                      0
# 1         0          1             0          4                      0
# 2         0          1             0          4                      1
# 3         0          3             1          3                      0
# 4         0          1             0          1                      0
#
#    cumulative_use_count  b2b  accident_ratio  pf_type  socarpass  socarsave  \
# 0                     2    0             100        2          0          0
# 1                     4    0               0        3          1          0
# 2                     4    0             100        3          1          0
# 3                     4    0               0        2          0          0
# 4                     1    0             100        1          0          0
#
#    start_hour  duration  accident_hour   repair_cost  insure_cost  \
# ...

# %%
test = socar_df[socar_df['test_set'] == 1]

# %%
import seaborn as sns
# %matplotlib inline

var = test.columns.values 

i = 0

t0 = socar_df.loc[socar_df['test_set']==0]
t1 = socar_df.loc[socar_df['test_set']==1]

sns.set_style('whitegrid')
plt.figure()
fig,ax = plt.subplots(7,4,figsize=(16,28))


for feature in var:
    i += 1 
    plt.subplot(7,4,i)
    sns.kdeplot(t0[feature], bw=0.5, label = 'test_set_0')
    sns.kdeplot(t1[feature], bw=0.5, label = 'test_set_1')

    plt.xlabel(feature,fontsize=12)
    locs, labels = plt.xticks()

    plt.tick_params(axis='both', which = 'major', labelsize=12)

plt.show()

# %%
fraud = socar_df[socar_df["fraud_YN"] == 1]

# %%
var = test.columns.values 

i = 0

t0 = fraud.loc[fraud['test_set']==0]
t1 = fraud.loc[fraud['test_set']==1]

sns.set_style('whitegrid')
plt.figure()
fig,ax = plt.subplots(7,4,figsize=(16,28))


for feature in var:
    i += 1 
    plt.subplot(7,4,i)
    sns.kdeplot(t0[feature], bw=0.5, label = 'test_set_0')
    sns.kdeplot(t1[feature], bw=0.5, label = 'test_set_1')

    plt.xlabel(feature,fontsize=12)
    locs, labels = plt.xticks()

    plt.tick_params(axis='both', which = 'major', labelsize=12)

plt.show()
